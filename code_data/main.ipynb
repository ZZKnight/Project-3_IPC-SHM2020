# %% [markdown]
# **Introduction**
#
# This program train and test the LSTM-FCN model for TSC using the time series of cable force or cable force ratio.

# %% [markdown]
# **Mount the google drive to this Colab notebook**

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# **Direct to the correct folder**

# %%
# %cd /content/drive/My\ Drive/code_data

# %% [markdown]
# **Install the Keras framework**

# %%
# !pip install Keras

# %% [markdown]
# **Model training**

# %%
# !python model_training.py

# %% [markdown]
# **Model testing**

# %%
# !python model_testing.py
